# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Parámetros

f_b = 30  # Frecuencia de muestreo en Hz
w_b = 2 * np.pi * f_b  # Frecuencia angular base
f_s = 2 * f_b  # Frecuencia de muestreo, el doble de f_b
w_s = 2 * w_b  # Frecuencia angular de muestreo

T = 1 / f_s  # Intervalo de tiempo entre muestras
L = 1  # Duración de la señal en segundos
N = int(Fs * L)  # Número de muestras

# Tiempo
t = np.linspace(0.0, L, N, endpoint=False)

# Señal X(t) = 10 cos(40π t) + 5 sin(30π t)
signal = 10 * np.cos(40 * np.pi * t) + 5 * np.sin(30 * np.pi * t)

# Cálculo de la Transformada de Fourier
yf = fft(signal)
xf = fftfreq(N, T)[:N // 2]

# Solo se necesitan las frecuencias positivas
yf = 2.0 / N * np.abs(yf[:N // 2])

# Visualización
plt.figure(figsize=(12, 6))

# Señal en el dominio del tiempo
plt.subplot(1, 2, 1)
plt.plot(t, signal, label='X(t)')
plt.title('Señal en el dominio del tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)

# Espectro en el dominio de la frecuencia
plt.subplot(1, 2, 2)
plt.plot(xf, yf, label='Transformada de Fourier')
plt.title('Transformada de Fourier')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud')
plt.grid(True)

print("3 - A")
plt.tight_layout()
plt.show()


print("3 - B")
print("Fb =", f_b, "Hz")
print("Wb =", w_b, "pi rad/seg")
print("Fs =", f_s, "Hz")
print("Ws =", w_s, "pi rad/seg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 T = 1 / f_s  # Intervalo de tiempo entre muestras
#      13 L = 1  # Duración de la señal en segundos
# ---> 14 N = int(Fs * L)  # Número de muestras
#      16 # Tiempo
#      17 t = np.linspace(0.0, L, N, endpoint=False)
#
# NameError: name 'Fs' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Parámetros
f_b = 30  # Frecuencia base en Hz
w_b = 2 * np.pi * f_b  # Frecuencia angular base en radianes/segundo
f_s = 2 * f_b  # Frecuencia de muestreo, el doble de f_b (según el criterio de Nyquist)
w_s = 2 * w_b  # Frecuencia angular de muestreo en radianes/segundo
T0 = 1 / f_s  # Período de muestreo en segundos

L = 1  # Duración de la señal en segundos
N = int(f_s * L)  # Número de muestras

# Tiempo
t = np.linspace(0.0, L, N, endpoint=False)

# Señal X(t) = 10 cos(40π t) + 5 sin(30π t)
signal = 10 * np.cos(40 * np.pi * t) + 5 * np.sin(30 * np.pi * t)

# Cálculo de la Transformada de Fourier
yf = fft(signal)
xf = fftfreq(N, T0)[:N // 2]

# Solo se necesitan las frecuencias positivas
yf = 2.0 / N * np.abs(yf[:N // 2])

# Visualización
plt.figure(figsize=(12, 6))

# Señal en el dominio del tiempo
plt.subplot(1, 2, 1)
plt.plot(t, signal, label='X(t)')
plt.title('Señal en el dominio del tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)

# Espectro en el dominio de la frecuencia
plt.subplot(1, 2, 2)
plt.plot(xf, yf, label='Transformada de Fourier')
plt.title('Transformada de Fourier')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Parámetros
f_b = 30  # Frecuencia de muestreo en Hz
w_b = 2 * np.pi * f_b  # Frecuencia angular base en radianes/segundo
f_s = 2 * f_b  # Frecuencia de muestreo, el doble de f_b
w_s = 2 * w_b  # Frecuencia angular de muestreo en radianes/segundo
T0 = 1 / f_s  # Período de muestreo en segundos

L = 1  # Duración de la señal en segundos
N = int(f_s * L)  # Número de muestras

# Tiempo
t = np.linspace(0.0, L, N, endpoint=False)

# Señal X(t) = 10 cos(40π t) + 5 sin(30π t)
signal = 10 * np.cos(40 * np.pi * t) + 5 * np.sin(30 * np.pi * t)

# Cálculo de la Transformada de Fourier
yf = fft(signal)
xf = fftfreq(N, T0)[:N // 2]

# Solo se necesitan las frecuencias positivas
yf = 2.0 / N * np.abs(yf[:N // 2])

# Visualización
plt.figure(figsize=(12, 6))

# Señal en el dominio del tiempo
plt.subplot(1, 2, 1)
plt.plot(t, signal, label='X(t)')
plt.title('Señal en el dominio del tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)

# Espectro en el dominio de la frecuencia
plt.subplot(1, 2, 2)
plt.plot(xf, yf, label='Transformada de Fourier')
plt.title('Transformada de Fourier')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout()
plt.show()

# Información sobre parámetros
print("3 - A")
print("Fb =", f_b, "Hz")
print("Wb =", w_b / np.pi, "π rad/seg")  # Frecuencia angular base en términos de π radianes por segundo
print("Fs =", f_s, "Hz")
print("Ws =", w_s / np.pi, "π rad/seg")  # Frecuencia angular de muestreo en términos de π radianes por segundo
# Out:
# 3 - A
# Fb = 30 Hz
# Wb = 59.99999999999999 π rad/seg
# Fs = 60 Hz
# Ws = 119.99999999999999 π rad/seg
